# %% [markdown]
# # Genel Özellikleri
# * GPU ve TPU lara ğcretsiz erişim sağlıyor .
# * Ortak çalışma imkanı sunar .
# * Not : # sayısına göre alt başlık yapıyor .

# %% [markdown]
# ## Merhaba

# %%
print('sa')
# Out:
# sa

# %%
birGundeSaniye=24*60*60
birGundeSaniye
# Out:
# 86400

# %%
print(type(birGundeSaniye))
# Out:
# <class 'int'>

# %% [markdown]
# ## CPU hakkında

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2299.998
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs mmio_stale_data retbleed
# bogomips	: 4599.99
# clflush size	: 64
# cache_alignment	: 64
# ...

# %% [markdown]
# ## Ram Hakkında

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13297192 kB
# MemFree:         8958948 kB
# MemAvailable:   12170460 kB
# Buffers:          268528 kB
# Cached:          3112072 kB
# SwapCached:            0 kB
# Active:           522524 kB
# Inactive:        3524748 kB
# Active(anon):       1080 kB
# Inactive(anon):   652112 kB
# Active(file):     521444 kB
# Inactive(file):  2872636 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:             33624 kB
# Writeback:             0 kB
# AnonPages:        666632 kB
# Mapped:           258976 kB
# Shmem:              1380 kB
# KReclaimable:     117768 kB
# Slab:             151908 kB
# SReclaimable:     117768 kB
# SUnreclaim:        34140 kB
# KernelStack:        4624 kB
# PageTables:        11216 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6648596 kB
# Committed_AS:    2731200 kB
# VmallocTotal:   34359738367 kB
# ...

# %% [markdown]
# # Veri Bilimi
# `Pythone` den :
# * Numpy
# * Matplotlib <br>
# kullanacağız .

# %%
import numpy as np
from matplotlib import pyplot as plt
ys=50+np.random.randn(50)
x=[x for x in range (len(ys))]

plt.plot(x,ys,'*')
plt.fill_between(x,ys,45,where= (ys>45),facecolor='m',alpha=0.5)

plt.title("Örnek Gösterim")
plt.show()

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x=alt.X('Miles_per_Gallon', bin=True),
  y='count()',
  color='Origin'
)
# Out:
# alt.Chart(...)

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

import altair as alt

interval = alt.selection_interval()

alt.Chart(cars).mark_point().encode(
  x='Horsepower',
  y='Miles_per_Gallon',
  color=alt.condition(interval, 'Origin', alt.value('lightgray'))
).properties(
  selection=interval
)
# Out:
# alt.Chart(...)

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# !ls "/gdrive/MyDrive/Calisma_ortami/"
# Out:
# Colab_CalismaOrtami.ipynb  rakamtanima_cnn.py.gdoc

# %%
import os
os.chdir("/gdrive/MyDrive/Calisma_ortami/")

# %%
# !ls
# Out:
# Colab_CalismaOrtami.ipynb  rakamtanima_cnn.py.gdoc

# %% [markdown]
# ## Kütüphane Kurulumları

# %%
# !pip install -q keras
import keras

# %%
# !apt-get install graphviz -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# graphviz is already the newest version (2.42.2-3build2).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %% [markdown]
# ### GPU Özelliklerinin Görüntülenmesi

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
import tensorflow_hub as hub

# %%
print("TF version : ",tf.__version__)
print("Hub version : ",hub.__version__)
print("GPU is","AVAILABLE" if tf.test.is_gpu_available() else "Nat AVAILABLE")
# Out:
# TF version :  2.12.0
# Hub version :  0.13.0
# GPU is AVAILABLE

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices ()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 13547754009064741759
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14343274496
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 16925709882139828451
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
# !python3 rakamtanima_cnn.py.gdoc
# Out:
# python3: can't open file '/gdrive/MyDrive/Calisma_ortami/rakamtanima_cnn.py.gdoc': [Errno 95] Operation not supported

# %%
# !ls
# Out:
# sample_data

# %%
# !kill -9 -1

# %%
# !kill -9 -1
