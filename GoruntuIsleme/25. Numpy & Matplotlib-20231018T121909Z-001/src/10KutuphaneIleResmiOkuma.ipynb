# %%
import numpy as nb
import matplotlib.pyplot as plt

# %%
# bir resme grafik olarak erişeceğiz
# cv2 yerine plt kullanıyoz
path="C:\\Users\\ibo_m\\Desktop\\Yapay Zeka\\Görüntü işleme\\25. Numpy & Matplotlib-20231018T121909Z-001\\input\\10.1 coins.jpg.jpg"
img=plt.imread(path)
plt.imshow(img)
plt.show() # bu da olması lazım .

# %%
print(img);print("type : ",type(img));print("img.shape : ",img.shape);print("img.ndim : ",img.ndim);print("img.size : ",img.size);print("img.dtype : ",img.dtype)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# type :  <class 'numpy.ndarray'>
# img.shape :  (474, 640, 3)
# img.ndim :  3
# img.size :  910080
# img.dtype :  uint8

# %%
# resmin channel değerlerine erişebiliyoz
# yani ! rgb ! değerleri
print("red channel",img[50,50,0]) # rgb olarak düşündüğümüzden 0 diyerek 50ye 50 noktasındaki kırmızı değerini öğreniyoruz
print("green channel",img[50,50,1])
print("blue channel",img[50,50,2])
print("rgb channel",img[50,50,:])
# Out:
# red channel 182
# green channel 162
# blue channel 111
# rgb channel [182 162 111]
