# %%
import numpy as np

# %% [markdown]
# **Görev: 5x5 boyutunda ve her elemanı 10 değerini alan bir array oluşturunuz**

# %%
arry1=np.ones([5,5])
arry1[:]=10
arry1
# Out:
# array([[10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.]])

# %% [markdown]
# rasgele sayı üret

# %%
random=np.random.randint(5,55,[7,7])
random
# Out:
# array([[29, 41, 43, 14,  8, 48,  6],
#        [20,  9,  9, 41, 23, 19, 33],
#        [22, 28, 51, 21, 11, 12, 25],
#        [15, 47, 37, 48, 44, 50, 28],
#        [27, 26, 31, 17,  7, 45, 22],
#        [ 6, 30,  7, 21,  7, 29, 20],
#        [34, 11, 33, 47, 27, 53, 25]])

# %%
random.max()
# Out:
# 53

# %%
random.min()
# Out:
# 6

# %% [markdown]
# **Görev: PIL ve matplotlib kullanarak örnek bir fotoğrafın okuma işlemini ve ekranda gösterme işlemini gerçekleştiriniz**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image

pic = Image.open('input/elma.jpeg')
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=212x192>

# %% [markdown]
# **Görev: Fotoğrafı NumPy array olarak dönüşüm işlemini gerçekleştiriniz ve tipini ve şeklini kontrol ediniz**

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr=np.asarray(pic)
print(type(pic_arr))
print(pic_arr.shape)
# Out:
# <class 'numpy.ndarray'>
# (192, 212, 3)

# %% [markdown]
# **Görev: imshow() fonksiyonunu kullanarak fotoğrafınızı ekrana bastırınız**

# %%
plt.imshow(pic_arr)

# %%
plt.imshow(pic)

# %% [markdown]
# **Görev: Bir adet mycopy isimli değişkeninizin kopyasını oluşturunuz**

# %% [markdown]
# **Görev: Oluşturduğunuz mycopy isimli değişkeni kırmızı ve mavi renk kanallarının elemanları 0 olacak şekilde ve sadece mavi renk kanalını kullanarak ekrana bastırınız**

# %%
mycopy = pic_arr.copy()
type(mycopy)
# Out:
# numpy.ndarray

# %%
mycopy[:,:,0]=0
mycopy[:,:,1]=0
plt.imshow(mycopy)
