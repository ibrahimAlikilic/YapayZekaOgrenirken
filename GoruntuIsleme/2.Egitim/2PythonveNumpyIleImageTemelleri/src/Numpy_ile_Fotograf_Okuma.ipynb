# %%
import numpy as np
import matplotlib.pyplot as plt # çizim kütüphanesidir
from PIL import Image # Python Image Labrary de import ediyoruz

# %%
ls # şu anda hangi dizindeyim
# Out:
# input/  Numpy_ile_Fotograf_Okuma.ipynb  NumpyTemelSeyler.ipynb

# %%
pic=Image.open('input/elma.jpeg')
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=212x192>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
# fotoğrafı arraye dönüştürüyoruz
pic_arr=np.asarray(pic)
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (192, 212, 3)

# %%
# şimdi de matplatlib ile resmimizi ekrana bastıracağız
plt.imshow(pic_arr)

# %%
pic_red=pic_arr.copy() # kopya oluşturduk
pic_red[:,:,0]# sadece kırmızı renk kanalına sahip oalnları yazdırıyorum.
# Out:
# array([[244, 244, 244, ..., 228, 228, 228],
#        [244, 244, 244, ..., 228, 228, 228],
#        [244, 244, 244, ..., 228, 228, 228],
#        ...,
#        [244, 244, 244, ..., 234, 234, 234],
#        [244, 244, 244, ..., 234, 234, 234],
#        [244, 244, 244, ..., 234, 234, 234]], dtype=uint8)

# %%
plt.imshow(pic_red[:,:,0]) # matplotlib kütüphanesi algılanan renkleri sarı renge yaklaştırmakta bu sebepten çıktı böyle.

# %%
plt.imshow(pic_arr[:,:,0],cmap='gray') # fotoğrafın kırmızı alanlarında beyaz yoğunlaşıyor

# %%
plt.imshow(pic_arr[:,:,1],cmap='gray') # yeşil için

# %%
plt.imshow(pic_arr[:,:,2],cmap='gray') # mavi için

# %%
# yeşil me vami kanal değerlerinin 0 yapıp o durumu inceleyeceğiz
pic_red[:,:,1]=0
pic_red[:,:,2]=0
plt.imshow(pic_red)
