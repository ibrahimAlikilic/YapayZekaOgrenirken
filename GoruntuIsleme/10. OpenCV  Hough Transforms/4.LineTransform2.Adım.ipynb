# %%
import cv2
import numpy as np

# %%
vid=cv2.VideoCapture("4.2 line.mp4.mp4")
while True:
    ret,frame=vid.read()
    frame=cv2.resize(frame,(640,480)) # çok büyüktü küçülttük
    # amaç sarı çizgileri ayırmak olduğundan hsv ye çevirip sarıyı ayıracağız
    hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
    # lower ve upper sarıları belirleyeceğim
    lower_yellow=np.array([18,94,140],np.uint8) # RENK KODUNU BULMAK İÇİN HSV RANGE CODE YELLOW diye google arat
    upper_yellow=np.array([48,255,255],np.uint8)
    
    mask=cv2.inRange(hsv,lower_yellow,upper_yellow)
    
    cv2.imshow("mask",mask)
    
    if cv2.waitKey(20)&0xFF==ord("q"):
        break
vid.release()
cv2.destroyAllWindows()

# %%
# köşeleri bulma işleminden devam ediyoruz
vid=cv2.VideoCapture("4.2 line.mp4.mp4")
while True:
    ret,frame=vid.read()
    frame=cv2.resize(frame,(640,480)) # çok büyüktü küçülttük
    # amaç sarı çizgileri ayırmak olduğundan hsv ye çevirip sarıyı ayıracağız
    hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
    # lower ve upper sarıları belirleyeceğim
    lower_yellow=np.array([18,94,140],np.uint8) # RENK KODUNU BULMAK İÇİN HSV RANGE CODE YELLOW diye google arat
    upper_yellow=np.array([48,255,255],np.uint8)
    
    mask=cv2.inRange(hsv,lower_yellow,upper_yellow)
    edges=cv2.Canny(mask,75,255)
    
    cv2.imshow("eds",edges)
    
    if cv2.waitKey(20)&0xFF==ord("q"):
        break
vid.release()
cv2.destroyAllWindows()

# %%
# şimdi sisteme bunların çizgi olduğunu söyleyeceğiz
vid=cv2.VideoCapture("4.2 line.mp4.mp4")
while True:
    ret,frame=vid.read()
    frame=cv2.resize(frame,(640,480)) # çok büyüktü küçülttük
    # amaç sarı çizgileri ayırmak olduğundan hsv ye çevirip sarıyı ayıracağız
    hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
    # lower ve upper sarıları belirleyeceğim
    lower_yellow=np.array([18,94,140],np.uint8) # RENK KODUNU BULMAK İÇİN HSV RANGE CODE YELLOW diye google arat
    upper_yellow=np.array([48,255,255],np.uint8)
    
    mask=cv2.inRange(hsv,lower_yellow,upper_yellow)
    edges=cv2.Canny(mask,75,255)
    
    lines=cv2.HoughLinesP(edges,1,np.pi/180,50,maxLineGap=50)
    for line in lines:
        x1,y1,x2,y2=line[0]
        cv2.line(frame,(x1,y1),(x2,y2),(0,255,0),5)
    
    cv2.imshow("frame with line",frame)
    
    if cv2.waitKey(20)&0xFF==ord("q"):
        break
vid.release()
cv2.destroyAllWindows()

# %%
# kendim beyaz kesiklileri de ekliyorum
vid=cv2.VideoCapture("4.2 line.mp4.mp4")
while True:
    ret,frame=vid.read()
    frame=cv2.resize(frame,(640,480)) # çok büyüktü küçülttük
    # amaç sarı çizgileri ayırmak olduğundan hsv ye çevirip sarıyı ayıracağız
    hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
    # lower ve upper sarıları belirleyeceğim
    lower_yellow=np.array([18,94,140],np.uint8) # RENK KODUNU BULMAK İÇİN HSV RANGE CODE YELLOW diye google arat
    upper_yellow=np.array([48,255,255],np.uint8)
    
    mask=cv2.inRange(hsv,lower_yellow,upper_yellow)
    edges=cv2.Canny(mask,75,255)
    
    lines=cv2.HoughLinesP(edges,1,np.pi/180,50,maxLineGap=50)
    for line in lines:
        x1,y1,x2,y2=line[0]
        cv2.line(frame,(x1,y1),(x2,y2),(0,255,0),5)
    
    sensitivity = 15
    lower_white = np.array([0,0,255-sensitivity])
    upper_white = np.array([255,sensitivity,255])
    mask_white=cv2.inRange(hsv,lower_white,upper_white)
    edges_white=cv2.Canny(mask_white,75,255)
    lines_white=cv2.HoughLinesP(edges_white,1,np.pi/180,50,maxLineGap=200)
    for line in lines_white:
        x1,y1,x2,y2=line[0]
        cv2.line(frame,(x1,y1),(x2,y2),(0,255,0),5)
    
    cv2.imshow("frame with line",frame)
    
    if cv2.waitKey(20)&0xFF==ord("q"):
        break
vid.release()
cv2.destroyAllWindows()
# galiba çizgiler net olmadığından binaları alıyor

# %%
import cv2
import numpy as np
# şimdi sisteme bunların çizgi olduğunu söyleyeceğiz
vid=cv2.VideoCapture(0)
while True:
    ret,frame=vid.read()
    frame=cv2.resize(frame,(640,480)) # çok büyüktü küçülttük
    # amaç sarı çizgileri ayırmak olduğundan hsv ye çevirip sarıyı ayıracağız
    hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
    # sarı
    lower_yellow=np.array([18,94,140],np.uint8) # RENK KODUNU BULMAK İÇİN HSV RANGE CODE YELLOW diye google arat
    upper_yellow=np.array([48,255,255],np.uint8)
    
    mask=cv2.inRange(hsv,lower_yellow,upper_yellow)
    edges=cv2.Canny(mask,75,255)
    
    lines=cv2.HoughLinesP(edges,1,np.pi/180,50,maxLineGap=50)
    for line in lines:
        x1,y1,x2,y2=line[0]
        cv2.line(frame,(x1,y1),(x2,y2),(0,255,0),5)
    # beyaz
    sensitivity = 15
    lower_white = np.array([0,0,255-sensitivity])
    upper_white = np.array([255,sensitivity,255])
    
    mask_white=cv2.inRange(hsv,lower_white,upper_white)
    edges_white=cv2.Canny(mask_white,75,255)
    
    lines_white=cv2.HoughLinesP(edges_white,1,np.pi/180,50,maxLineGap=50)
    for line in lines_white:
        x1,y1,x2,y2=line[0]
        cv2.line(frame,(x1,y1),(x2,y2),(0,255,0),5)
    
    cv2.imshow("frame with line",frame)
    
    if cv2.waitKey(20)&0xFF==ord("q"):
        break
vid.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 18
#      15 edges=cv2.Canny(mask,75,255)
#      17 lines=cv2.HoughLinesP(edges,1,np.pi/180,50,maxLineGap=50)
# ---> 18 for line in lines:
#      19     x1,y1,x2,y2=line[0]
#      20     cv2.line(frame,(x1,y1),(x2,y2),(0,255,0),5)
#
# TypeError: 'NoneType' object is not iterable
