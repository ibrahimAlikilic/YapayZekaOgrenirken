# %%
# %cat /etc/lsb-release
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=22.04
# DISTRIB_CODENAME=jammy
# DISTRIB_DESCRIPTION="Ubuntu 22.04.3 LTS"

# %% [markdown]
# # Depolama Alanı Güncelleme

# %%
# !apt-get update
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Ign:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [976 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,288 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,499 kB]
# ...

# %% [markdown]
# # Bulunduğum Dizin

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
# # Zip ten çıkarma

# %%
# !unzip "/content/drive/MyDrive/boston_dynamics_spot/yolov4.zip"
# Out:
# Archive:  /content/drive/MyDrive/boston_dynamics_spot/yolov4.zip
#    creating: yolov4/
#    creating: yolov4/darknet/
#    creating: yolov4/darknet/build/
#    creating: yolov4/darknet/build/darknet/
#    creating: yolov4/darknet/build/darknet/x64/
#    creating: yolov4/darknet/build/darknet/x64/data/
#    creating: yolov4/darknet/build/darknet/x64/data/labels/
#   inflating: yolov4/darknet/build/darknet/x64/data/labels/96_0.png
#   inflating: yolov4/darknet/build/darknet/x64/data/labels/87_4.png
#   inflating: yolov4/darknet/build/darknet/x64/data/labels/97_2.png
#   inflating: yolov4/darknet/build/darknet/x64/data/labels/115_4.png
#   inflating: yolov4/darknet/build/darknet/x64/data/labels/88_6.png
#   inflating: yolov4/darknet/build/darknet/x64/data/labels/52_2.png
#   inflating: yolov4/darknet/build/darknet/x64/data/labels/62_0.png
#   inflating: yolov4/darknet/build/darknet/x64/data/labels/35_1.png
#   inflating: yolov4/darknet/build/darknet/x64/data/labels/70_5.png
# ...

# %% [markdown]
# # Adres Ayarlama

# %%
# %cd /content/yolov4/darknet
# Out:
# /content/yolov4/darknet

# %%
# %pwd
# Out:
# '/content/yolov4/darknet'

# %% [markdown]
# ## Dosyalarımı linux un anlayabileceği hale getirmemi sağlayacak olan kütüphaneyi indirelim

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 384 kB of archives.
# After this operation, 1,367 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 dos2unix amd64 7.4.2-2 [384 kB]
# Fetched 384 kB in 1s (629 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dos2unix.
# ...

# %% [markdown]
# ## Dosyaları unix'e çevirme

# %%
# !find . -type f -print0 | xargs -0 dos2unix
# kodu çalıştırırken bu satırı atlamışım diğer projelerde hata verme ihtimali var dikkat et

# %% [markdown]
# # Darknet uygulamalarını çalıştırabilmek için linux'tan izin aşaması

# %%
# !chmod +x /content/yolov4/darknet

# %% [markdown]
# # Darknet dosyalarını çalıştırma komutu

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:945:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   945 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1443:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1443 |         char buff[100];
# ...

# %% [markdown]
# # Darknet test

# %%
# !./darknet detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights data/dog.jpg
# Out:
#  CUDA-version: 12020 (12020), cuDNN: 8.9.6, GPU count: 1
#  OpenCV version: 4.5.4
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
# ...

# %% [markdown]
# çıktı darknet içerisindeki predictions.jpg dir.

# %% [markdown]
# # Var olan backup silip kendi oluşturmuş olduğumuz backup dosyasına bağlantı kuracağız

# %% [markdown]
# ## Silme

# %%
# !rm /content/yolov4/darknet/backup -r

# %% [markdown]
# ## Drive backup bağlantısı

# %%
# !ln -s /content/drive/MyDrive/boston_dynamics_spot/spot_weights/backup /content/yolov4/darknet

# %%
# %pwd
# Out:
# '/content/yolov4/darknet'

# %%
# !chmod +r /content/yolov4/darknet/spot_data/spot_testing.txt

# %% [markdown]
# # Eğitime başlayalım

# %%
# !./darknet detector train spot_data/spot.data spot_yolov4.cfg yolov4.conv.137 -map -dont_show
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#  total_bbox = 804286, rewritten_bbox = 0.072362 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.014877, iou_loss = 0.000000, total_loss = 0.014877
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.736867), count: 5, class_loss = 4.271488, iou_loss = 9.868263, total_loss = 14.139751
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.707541), count: 6, class_loss = 6.849180, iou_loss = 1.128015, total_loss = 7.977195
#  total_bbox = 804297, rewritten_bbox = 0.072361 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000891, iou_loss = 0.000000, total_loss = 0.000891
# ...

# %% [markdown]
# sonuç grafiğine ulaştığımız adres : /content/yolov4/darknet/chart.png
